# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Death.csv")
# Drop the missing values rows
df = df.dropna()
df.head(10)
# Out:
#     _id               NEIGHBORHOOD  BLACKdeaths  Black MD AGE AT DEATH  \
# 0     1                SOUTH SHORE          0.0                    0.0
# 4     5                SAINT CLAIR          5.0                   67.5
# 5     6                   WEST END          5.0                   76.7
# 7     8          ARLINGTON HEIGHTS         10.0                   55.0
# 8     9             STRIP DISTRICT          7.0                   76.7
# 9    10                  FAIRYWOOD         11.0                   62.5
# 11   12  MOUNT OLIVER NEIGHBORHOOD          9.0                   67.5
# 12   13              EAST CARNEGIE          9.0                   72.5
# 14   15       CALIFORNIA-KIRKBRIDE         16.0                   70.0
# 15   16             CHARTIERS CITY         20.0                   70.0
#
#     WHITEdeaths  White MD AGE AT DEATH  TOTALdeaths*  TOTAL MD AGE AT DEATH
# 0           0.0                    0.0           0.0                    0.0
# ...
